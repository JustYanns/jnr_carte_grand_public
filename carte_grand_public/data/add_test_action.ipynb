# %%
import pandas as pd

# %%
df=  pd.read_csv("./actions_grand_public_carte.csv")

# %%
action = {
    'organisateur': "DGPR",
    'etat_dossier': "labellisé",
    'description_projet': "Projet test",
    'nom': "Action fictive",
    'description_action': "Action fictive pour tests",
    'lien_programme': "https://www.ecologie.gouv.fr/",
    'est_dematerialisee': False,
    'adresse': "1 Pl. Carpeaux, 92800 Puteaux",
    'nom_commune': "Puteaux",
    'nom_departement': "Hauts-de-Seine",
    'insee_dep': "92",
    'date_debut': "13/09/2023",
    'date_fin': "13/09/2023",
    'type_action_str': "Action test",
    'est_grand_public': True,
    'public_cible_str': "Tous publics",
    'risque_cible_str': "Tous risques",
    'est_atelier_jeux': True,
    'est_atelier_sensibilisation': True,
    'est_conference': True,
    'est_exercice_de_gestion_de_crise': True,
    'est_exposition': True,
    'est_formation': True,
    'est_reunion_d_information': True,
    'est_spectacle': True,
    'est_visite_en_plein_air': True,
    'est_visite_en_interieur': True,
    'est_autre': True,
    'est_tous_public': True,
    'est_famille': True,
    'est_jeune_public': True,
    'est_seniors': True,
    'est_risques_naturels': True,
    'est_risques_technologiques': True,
    'est_inondations': True,
    'est_feux_de_foret': True,
    'est_tempete_cyclone': True,
    'est_seisme': True,
    'est_eruption_volcanique': True,
    'est_mouvement_de_terrain': True,
    'est_risques_littoraux': True,
    'est_avalanche': True,
    'est_radon': True,
    'est_accidents_industriels': True,
    'est_accidents_nucleaires': True,
    'est_rupture_de_barrage': True,
    'est_transport_de_matieres_dangereuses': True,
    'lat' : 48.893771,
    'lon' : 2.239719
}

# %%
df = df.append(action, ignore_index=True)
# Out:
# /tmp/ipykernel_106967/2367157693.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(action, ignore_index=True)

# %%
df
# Out:
#                                        organisateur     etat_dossier  \
# 0    Communauté d'agglomération Saumur Val de Loire          accepte
# 1    Communauté d'agglomération Saumur Val de Loire          accepte
# 2                    SYNDICAT DES ETANGS CORREZIENS  en_construction
# 3                    SYNDICAT DES ETANGS CORREZIENS  en_construction
# 4                    SYNDICAT DES ETANGS CORREZIENS  en_construction
# ..                                              ...              ...
# 201                                    LAKOUDIGITAL  en_construction
# 202                                    LAKOUDIGITAL  en_construction
# 203                                    LAKOUDIGITAL  en_construction
# 204                  CARPENTER ENGINEERED FOAMS SAS   en_instruction
# 205                                            DGPR        labellisé
#
#                                     description_projet  \
# 0    Dans le cadre du Programme d’Actions de Préven...
# ...

# %%
df.to_csv("actions_grand_public_carte_3.csv")
